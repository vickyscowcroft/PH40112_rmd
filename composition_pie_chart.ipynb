# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

import matplotlib
font = {'size'   : 16}

matplotlib.rc('font', **font)

# %%
# Pie chart
labels = ['Baryons', 'Dark Matter', 'Dark Energy']
omegas = ['$\Omega_{b}$', '$\Omega_{dm}$', '$\Omega_{\Lambda}$']
sizes = [0.05, 0.27, 0.68,]

# %%
# only "explode" the 2nd slice (i.e. 'Hogs')
explode = (0.2, 0.0, 0.0)

# %%
#def make_autopct(sizes, omegas):
#    sizes = sizes
#    omegas = omegas
#    def my_autopct(sizes, omegas):
#        return '$\Omega_{1:s}$ = 2:d$'.format(omegas, sizes)
#    return my_autopct

#def func(sizes, omegas):
#    om_string = omegas + "$ = $" + str(sizes)
#    return om_string

# %%
func(sizes[0], omegas[0])
# Out:
# '$\\Omega_{b}$$ = $0.05'

# %%
#add colors
colors = ['#ff9999','#66b3ff','#99ff99']

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(111)



wedges, texts, autotexts = ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.0f%%',
        shadow=False, startangle=90, wedgeprops={"edgecolor":"grey",'linewidth': 1})
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.tight_layout()

ax1.legend(wedges, recipe,
          loc="upper right")

plt.setp(autotexts, size=16, weight="bold")

plt.savefig('compo-pie-chart.jpg', dpi=600, bbox_inches='tight')

# %%
recipe = ['$\Omega_{b}$ = 0.05', '$\Omega_{dm}$ = 0.27', '$\Omega_{\Lambda}$ = 0.68']

# %%
wedges, texts, autotexts = ax1.pie(sizes, autopct=recipe,
                                  textprops=dict(color="w"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-3ac855ee1a4f> in <module>
#       1 wedges, texts, autotexts = ax1.pie(sizes, autopct=recipe,
# ----> 2                                   textprops=dict(color="w"))
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
# ...

# %%
#autopct='%1.0f%%'

# %%
def my_autopct(pct, recipe):
    return '{1:s} = {2:d$}'.format(str(omegas), sizes)

for i in np.arange(len(sizes)):
        
    print(my_autopct(sizes[i], omegas[i]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-1aef15eec382> in <module>
#       4 for i in np.arange(len(sizes)):
#       5
# ----> 6     print(my_autopct(sizes[i], omegas[i]))
#
# <ipython-input-43-1aef15eec382> in my_autopct(sizes, omegas)
#       1 def my_autopct(sizes, omegas):
# ----> 2     return '{1:s} = {2:d$}'.format(str(omegas), sizes)
#       3
#       4 for i in np.arange(len(sizes)):
#       5
#
# ValueError: Unknown format code 's' for object of type 'float'

# %%
str(omegas[0])
# Out:
# '$\\Omega_{b}$'

# %%
omegas.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-74e19a1eb0bf> in <module>
# ----> 1 omegas.type()
#
# AttributeError: 'list' object has no attribute 'type'
